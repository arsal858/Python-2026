# %%
data={'name':'Arslan','age':40}
def main():
    for name in data:
        print(name)
main()
# Out:
# name
# age

# %%
data={'name':'Arslan','age':40}
def main():
    for i in data:
        print(i)
main()
# Out:
# name
# age

# %%
def main():
    spacecrafto={'name':'Voyager 1','distance':173}
    print(create_report(spacecrafto))
def create_report(view):
    return f"""
    =========report==========
    name: {view['name']}
    distance: {view['distance']}
    ===============================
    """
main()
# Out:
#     =========report==========
#     name: Voyager 1
#     distance: 173
# ...

# %%
def main():
    spacecrafto={'name':'Voyager 1'}
    spacecrafto.update({'distance':163,'oribit':'West'})
    print(create_report(spacecrafto))
def create_report(view):
    return f"""
    =========report==========
    name: {view['name']}
    distance: {view.get('distance','Unkwon')}
    ===============================
    """
main()
# Out:
#     =========report==========
#     name: Voyager 1
#     distance: 163
# ...

# %%
# distances={
#     'Voyger 1': 163
#     'Voyger 2': 137
#     'Voyger 3': 178
#     'Voyger 4':188
# }
# def main():
#     return f'Every man is {convert_to_au(distance) }'
# def convert_to_au(au):
#     distace=

# %%
s=input('enter')
for i in s:
    i=i.replace([['i','o','u']],'')
    print(i)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 3
#       1 s=input('enter')
#       2 for i in s:
# ----> 3     i=i.replace([['i','o','u']],'')
#       4     print(i)
#
# TypeError: replace() argument 1 must be str, not list
