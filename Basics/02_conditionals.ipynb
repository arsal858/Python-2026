# %%
# conditionals are powerful way of excuting conditions
x=int(input('Enter x'))
y=int(input('Enter y'))
if x>y:
    print('x is not equla to y')
elif x<y:
    print('X is not equal to y')
else:
    print('x is equal to y')
# Out:
# X is not equal to y

# %%
x=int(input('Enter x: '))
y=int(input('Enter y: '))
if x>y or x<y:
    print('x is not equal to y')
else:
    print('x is equal to y')
# Out:
# x is not equal to y

# %%
x=int(input('Enter x: '))
y=int(input('Enter y: '))
if x!=y:
    print('X is not equal to y')
else:
    print('X is equal to y')
# Out:
# X is not equal to y

# %%
# grading sytem using conditionals
marks=int(input('Enter Marks: '))
if marks >=90 and marks<=100:
    print('Grade: A')
elif marks >=80 and marks<=89:
    print('Grade:B')
elif marks >=70 and marks <=79:
    print('Grade: C')
elif marks >=60 and marks<=69:
    print('Grade: D')
else:
    print('Grade: F')
# Out:
# Grade: D

# %%
def main():
    x=int(input('Enter x'))
    if is_even(x):
        return 'Even'
    else:
        return 'Odd'
def is_even(n):
    return 'Even' if n%2==0 else 'Odd'
main()
# Out:
# 'Even'

# %%
# match case
n=input('Please Enter the name')
match n:
    case 'Arslan':
        print('Muhammad Arslan Shahzad')
    case 'Shahzad':
         print('Muhammad Arslan Shahzad')
    case 'Shahzad':
         print('Muhammad Arslan Shahzad')
    case _:
          print('Someone else')
# Out:
# Someone else

# %%
# n=input('Entre Your Name: ')
# match n:
    # case 'arslan'
