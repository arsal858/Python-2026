# %%
try:
    print('Arslan Shahzad',world)
except Exception as e:
    print(e)
finally:
    print('The code is executed')
# Out:
# name 'world' is not defined
# The code is executed

# %%
while True:
    try:
        x=int(input('Enter the Number'))
    except ValueError:
        print('X is not an integer')
    else:
        break
print(f'X is {x}')
# Out:
# X is not an integer
# X is not an integer
# X is not an integer
# X is not an integer
# X is not an integer
# X is 7

# %%
def  main():
    x=get_int()
    return f'X is {x}'
def get_int():
    while True:
        try:
            x=int(input('Enter your number'))
            break
        except ValueError:
            print('x is not an integer')
        return x
main()
# Out:
# 'X is None'

# %%
def main():
    height=int(input('Height:'))
    return pyrammid(height)
def pyrammid(n):
    for i in range(n):
        print('#'*i)
main()
# Out:
# #
# ##
# ###
# ####
